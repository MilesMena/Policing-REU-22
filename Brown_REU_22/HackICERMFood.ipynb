# %%
import geopandas as gpd
import pandas as pd
import altair as alt
import matplotlib.pyplot as plt
import descartes

# %% [markdown]
# https://jcutrer.com/python/learn-geopandas-plotting-usmaps

# %%
df_income = pd.read_csv('pvd-vendors/income.csv')

# %%
df_income[df_income['GEOID'].apply(lambda x: len(str(x)) > 10)]
# Out:
#     Unnamed: 0        GEOID  \
# 0            1  44007014200
# 2            2  44007011200
# 4            3  44007016400
# 5            4  44007003300
# 7            5  44007015400
# ..         ...          ...
# 276        141  44007012802
# 278        142  44007015900
# 279        143  44007011901
# 280        144  44007002400
# 283        145  44007011301
#
#                                                   NAME    variable estimate  \
# 0    Census Tract 142, Providence County, Rhode Island  B19013_001    87857
# 2    Census Tract 112, Providence County, Rhode Island  B19013_001    62700
# 4    Census Tract 164, Providence County, Rhode Island  B19013_001    39561
# 5     Census Tract 33, Providence County, Rhode Island  B19013_001    79276
# 7    Census Tract 154, Providence County, Rhode Island  B19013_001    50000
# ..                                                 ...         ...      ...
# 276  Census Tract 128.02, Providence County, Rhode ...  B19013_001    84453
# ...

# %%
df_income = pd.read_csv('pvdcty_income.csv', skipinitialspace=True, usecols = ['geometry'])

# %%
df['']df_income.iloc[:,0:0]
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df_income.geometry.apply(lambda x: str(x))
# Out:
# 'nan'

# %%
gpd.datasets.available
# Out:
# ['naturalearth_cities', 'naturalearth_lowres', 'nybb']

# %%
states.crs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-2ae4e9a96f37> in <module>
# ----> 1 states.crs
#
# NameError: name 'states' is not defined

# %% [markdown]
# ## GEOPANDAS

# %%
RI = gpd.read_file('tl_2021_44_tract.shp')

# %%
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID    NAME             NAMELSAD  MTFCC  \
# 0      44      005  041200  44005041200     412     Census Tract 412  G5020
# 1      44      005  040303  44005040303  403.03  Census Tract 403.03  G5020
# 2      44      007  012602  44007012602  126.02  Census Tract 126.02  G5020
# 3      44      007  012802  44007012802  128.02  Census Tract 128.02  G5020
# 4      44      007  013300  44007013300     133     Census Tract 133  G5020
#
#   FUNCSTAT      ALAND   AWATER     INTPTLAT      INTPTLON  \
# 0        S    1419519  2270967  +41.5102348  -071.3296377
# 1        S    3820823     9444  +41.5432837  -071.2995419
# 2        S   20960505   737269  +41.8973171  -071.4965197
# 3        S    5231974    54439  +41.9839979  -071.5315808
# 4        S  131446005  2835602  +41.7887835  -071.7349343
#
#                                             geometry
# 0  POLYGON ((-71.33559 41.51958, -71.33283 41.521...
# ...

# %%
pvdCounty = RI[RI.COUNTYFP=='007']
#pvdCounty.info()
pvdCounty['NAME']= pvdCounty['NAME'].astype(str).astype(float)
pvd = pvdCounty[pvdCounty.NAME < 40]
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 145 entries, 2 to 249
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   STATEFP   145 non-null    object
#  1   COUNTYFP  145 non-null    object
#  2   TRACTCE   145 non-null    object
#  3   GEOID     145 non-null    object
#  4   NAME      145 non-null    object
#  5   NAMELSAD  145 non-null    object
#  6   MTFCC     145 non-null    object
#  7   FUNCSTAT  145 non-null    object
#  8   ALAND     145 non-null    int64
#  9   AWATER    145 non-null    int64
#  10  INTPTLAT  145 non-null    object
#  11  INTPTLON  145 non-null    object
#  12  geometry  145 non-null    geometry
# dtypes: geometry(1), int64(2), object(10)
# memory usage: 15.9+ KB
# <ipython-input-5-67dc5bcf7a55>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
pvd.plot()
# Out:
# <AxesSubplot:>

# %%
pvd.boundary.plot(color =  'gray',linewidth = .25)
# Out:
# <AxesSubplot:>

# %%
pvd.plot(cmap='magma', figsize=(6, 6))
# Out:
# <AxesSubplot:>

# %%
providence.head()
providence.crs
providence.plot()
# Out:
# <AxesSubplot:>

# %%
providence.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID    NAME             NAMELSAD  MTFCC  \
# 0      44      005  041200  44005041200     412     Census Tract 412  G5020
# 1      44      005  040303  44005040303  403.03  Census Tract 403.03  G5020
# 2      44      007  012602  44007012602  126.02  Census Tract 126.02  G5020
# 3      44      007  012802  44007012802  128.02  Census Tract 128.02  G5020
# 4      44      007  013300  44007013300     133     Census Tract 133  G5020
#
#   FUNCSTAT      ALAND   AWATER     INTPTLAT      INTPTLON  \
# 0        S    1419519  2270967  +41.5102348  -071.3296377
# 1        S    3820823     9444  +41.5432837  -071.2995419
# 2        S   20960505   737269  +41.8973171  -071.4965197
# 3        S    5231974    54439  +41.9839979  -071.5315808
# 4        S  131446005  2835602  +41.7887835  -071.7349343
#
#                                             geometry
# 0  POLYGON ((-71.33559 41.51958, -71.33283 41.521...
# ...

# %%
data = [[41.824457494172485, -71.40706551534042], ]
#     41.824457494172485, -71.40706551534042
# Create the pandas DataFrame
current = pd.read_csv('pvd-vendors/vendors.csv')
current[['lat', 'long']] = current['Lat/Lon'].str.split(',', expand=True)
# print dataframe.
current
# Out:
#                                  Name  \
# 0                       Apsara Palace
# 1                  East Side Pockets
# 2                           Flatbread
# 3                Heng Thai Rotisserie
# 4                       Hometown Poke
# 5                   Hope Street Pizza
# 6                          Ivy Tavern
# 7            Kabob and Curry (Indian)
# 8            Khaosan Thai Street Food
# 9               Lims (Thai and Sushi)
# 10  Machupicchu Restaurant (Peruvian)
# 11                        Noodles 102
# 12           Not Just Snacks (Indian)
# 13              Pasta Beach (Italian)
# 14            Pho Horn’s (Vietnamese)
# 15                     Piemonte Pizza
# 16               Pizza Pie-er (pizza)
# 17                 Plant City (vegan)
# 18                   Pokeworks (Poke)
# 19                         Saladworks
# 20        The District (wings, pizza)
# 21        Wara Wara (Japanese fusion)
# 22     Xaco Taco (burritos and tacos)
# ...

# %%
import altair as alt
import gpdvega 
# https://iliatimofeev.github.io/gpdvega/
# https://altair-viz.github.io/altair-tutorial/README.html

bg = alt.Chart(pvd).mark_geoshape(
).encode( 
).properties( 
    width=800,
    height=500
)

points = alt.Chart(current).mark_circle(color='#ffffff').encode(
    latitude='lat:Q',
    longitude='long:Q',
    size=alt.value(50),
)

bg + points
# Out:
# C:\Users\menam\anaconda3\lib\site-packages\altair\utils\data.py:226: AltairDeprecationWarning: alt.pipe() is deprecated, and will be removed in a future release. Use toolz.curried.pipe() instead.
#   warnings.warn(
# C:\Users\menam\anaconda3\lib\site-packages\pandas\core\frame.py:1549: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   warnings.warn(
# C:\Users\menam\anaconda3\lib\site-packages\altair\utils\data.py:226: AltairDeprecationWarning: alt.pipe() is deprecated, and will be removed in a future release. Use toolz.curried.pipe() instead.
#   warnings.warn(
# alt.LayerChart(...)

# %%
pvd_income = pvd.merge(df_income, how = 'left', on = 'GEOID')
gpd_pvd_income = gpd.GeoDataFrame(
    pvd_income[['variable','geometry_x','estimate', 'GEOID']], geometry='geometry_x')

# %%
bg = alt.Chart(gpd_pvd_income).mark_geoshape(
).encode( color = 'estimate'
).properties( 
    width=800,
    height=500
)


points = alt.Chart(current).mark_circle(color='#ffffff').encode(
    latitude='lat:Q',
    longitude='long:Q',
    size=alt.value(50),

)

bg + points
# Out:
# C:\Users\menam\anaconda3\lib\site-packages\pandas\core\frame.py:1549: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   warnings.warn(
# alt.LayerChart(...)
